# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as sim

impulse = np.zeros((51,51))
impulse[25,25] = 1.0
my_filter = np.ones((3,3)) / 9
response = sim.convolve(impulse, my_filter)
plt.figure()
plt.imshow(response)
plt.show()

# %%
cat = plt.imread('./files/PMLSdata/16catphoto/bwCat.tif')
response = sim.convolve(cat, my_filter)
plt.figure()
plt.imshow(response)
plt.show()

# %%
gauss = np.loadtxt('./files/PMLSdata/16catphoto/gauss_filter.csv',delimiter=',')
print(gauss)
# Out:
# [[  3.73740000e-14   1.19480000e-13   3.61850000e-13 ...,   3.61850000e-13
#     1.19480000e-13   3.73740000e-14]
#  [  1.19480000e-13   3.81950000e-13   1.15680000e-12 ...,   1.15680000e-12
#     3.81950000e-13   1.19480000e-13]
#  [  3.61850000e-13   1.15680000e-12   3.50350000e-12 ...,   3.50350000e-12
#     1.15680000e-12   3.61850000e-13]
#  ...,
#  [  3.61850000e-13   1.15680000e-12   3.50350000e-12 ...,   3.50350000e-12
#     1.15680000e-12   3.61850000e-13]
#  [  1.19480000e-13   3.81950000e-13   1.15680000e-12 ...,   1.15680000e-12
#     3.81950000e-13   1.19480000e-13]
#  [  3.73740000e-14   1.19480000e-13   3.61850000e-13 ...,   3.61850000e-13
#     1.19480000e-13   3.73740000e-14]]
